# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\Kunal Arya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
credits = pd.read_csv('credits.csv')
keywords = pd.read_csv('keywords.csv')

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
credit_key = pd.merge(credits, keywords)
credit_key
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 46491  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 46492  [{'cast_id': 1002, 'character': 'Sister Angela...
# 46493  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 46494  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 46495                                                 []
#
#                                                     crew      id  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
len(credits)
# Out:
# 45476

# %%
len(keywords)
# Out:
# 46419

# %%
len(movies_metadata)
# Out:
# 45466

# %%
len(keywords)
# Out:
# 46419

# %%
movies_metadata.loc[19730]
# Out:
# adult                                                   - Written by Ørnås
# belongs_to_collection                                             0.065736
# budget                                    /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# genres                   [{'name': 'Carousel Productions', 'id': 11176}...
# homepage                 [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# id                                                              1997-08-20
# imdb_id                                                                  0
# original_language                                                    104.0
# original_title                    [{'iso_639_1': 'en', 'name': 'English'}]
# overview                                                          Released
# popularity                                                             NaN
# poster_path                                                   Midnight Man
# ...

# %%
new_movies = movies_metadata.drop([19730, 29503, 35587])
new_movies["id"] = pd.to_numeric(new_movies["id"])

# %%
new_movies["id"]
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45463, dtype: int64

# %%
# www.imdb.com/title/

# %%
all_df = pd.merge(new_movies, credit_key, on="id")
all_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 46623  False                                                NaN         0
# 46624  False                                                NaN         0
# 46625  False                                                NaN         0
# 46626  False                                                NaN         0
# 46627  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
all_df[["homepage"]]
# Out:
# http://www.georgecarlin.com                                   12
# http://movies.warnerbros.com/pk3/                              8
# http://www.daysofdarknessthemovie.com/                         8
# http://www.dealthemovie.com/                                   8
# http://www.pokemon.com/us/movies/movie-pokemon-4ever-2002/     8
#                                                               ..
# http://www.9dollars99movie.com/                                1
# http://www.furious7.com/                                       1
# http://www.dtifcambodia.com                                    1
# http://www.soldierofgod.net/                                   1
# http://www.thefilmfactory.co.uk/hallamfoe/                     1
# Name: homepage, Length: 7600, dtype: int64

# %%
cred = credits.loc[0]['cast']

# %%
ast.literal_eval(cred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-856e5be3cfed> in <module>
# ----> 1 ast.literal_eval(cred)
#
# NameError: name 'ast' is not defined

# %%
cast = all_df["cast"]
cast
# Out:
# 0        [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1        [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2        [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3        [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4        [{'cast_id': 1, 'character': 'George Banks', '...
#                                ...
# 46623    [{'cast_id': 0, 'character': '', 'credit_id': ...
# 46624    [{'cast_id': 1002, 'character': 'Sister Angela...
# 46625    [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 46626    [{'cast_id': 2, 'character': '', 'credit_id': ...
# 46627                                                   []
# Name: cast, Length: 46628, dtype: object

# %%
type(cast.loc[0])
# Out:
# str

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
len(df)
# Out:
# 46164

# %%
type(test["release_date"].loc[0])
# Out:
# str

# %%
test = df
test
# Out:
#                                    belongs_to_collection  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                    NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                    NaN
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 46623                                                NaN
# 46624                                                NaN
# 46625                                                NaN
# 46626                                                NaN
# 46627                                                NaN
#
#                                                   genres    imdb_id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  tt0114709
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  tt0113497
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  tt0113228
# ...

# %%
import numpy as np
# "genres", "cast", "crew", "keywords"
# test["belongs_to_collection"].replace({np.nan: "{}"}, inplace=True)
test["belongs_to_collection"] = test["belongs_to_collection"].fillna("{}")
test["genres"] = test["genres"].fillna("{}")
test["cast"] = test["cast"].fillna("{}")
test["crew"] = test["crew"].fillna("{}")
test["keywords"] = test["keywords"].fillna("{}")
test
# Out:
# C:\Users\Kunal Arya\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Kunal Arya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Kunal Arya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
wow = test.apply(lambda x: [ast.literal_eval(x["cast"]), ast.literal_eval(x["crew"]), x["id"], ast.literal_eval(x["keywords"])], axis=1, result_type='broadcast')

# %%
wow = test
convert_columns = ["belongs_to_collection", "genres", "cast", "crew", "keywords"]

for convert in convert_columns:
    wow[convert] = wow[convert].map(lambda x: [ast.literal_eval(x)])
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Kunal Arya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-172-5db55a308d02>", line 5, in <module>
#     wow[convert] = wow[convert].map(lambda x: [ast.literal_eval(x)])
#
#   File "C:\Users\Kunal Arya\anaconda3\lib\site-packages\pandas\core\series.py", line 3630, in map
#     new_values = super()._map_values(arg, na_action=na_action)
#
#   File "C:\Users\Kunal Arya\anaconda3\lib\site-packages\pandas\core\base.py", line 1145, in _map_values
#     new_values = map_f(values, mapper)
#
#   File "pandas\_libs\lib.pyx", line 2329, in pandas._libs.lib.map_infer
#
#   File "<ipython-input-172-5db55a308d02>", line 5, in <lambda>
#     wow[convert] = wow[convert].map(lambda x: [ast.literal_eval(x)])
#
#   File "C:\Users\Kunal Arya\anaconda3\lib\ast.py", line 46, in literal_eval
# ...

# %%
import ast
wow = test.apply(lambda x: [ast.literal_eval(x["belongs_to_collection"]), ast.literal_eval(x["genres"]), x["imdb_id"], x["original_language"], x["overview"], x["popularity"], x["release_date"], x["runtime"], x["tagline"], x["title"], x["vote_average"], ast.literal_eval(x["cast"]), ast.literal_eval(x["crew"]), ast.literal_eval(x["keywords"])], axis=1, result_type='broadcast')
# wow = test.apply(lambda x: [ast.literal_eval(x["belongs_to_collection"]), ast.literal_eval(x["genres"])], axis=1, result_type='broadcast')

# %%
# Out:
#                                    belongs_to_collection  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                     {}
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                     {}
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 46623                                                 {}
# 46624                                                 {}
# 46625                                                 {}
# 46626                                                 {}
# 46627                                                 {}
#
#                                                   genres    imdb_id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  tt0114709
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  tt0113497
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  tt0113228
# ...

# %%
wow.to_json('movie_data.json', orient="index")

# %%
with open('movie_data.json', 'w') as outfile:
    outfile.write(wow_json)

# %%
parsed = json.loads(wow_json)
print(json.dumps(parsed, indent=4))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
all_df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew', 'keywords'],
#       dtype='object')

# %%
# Status should be released
# Append http://image.tmdb.org/t/p/w185/ to poster path

# %%
c = "belongs_to_collection, genres, imdb_id, original_language, overview, popularity, release_date, runtime, tagline, title, vote_average, cast, crew, keywords" 
filtered_columns = c.split(", ")

# %%
all_df = all_df[all_df["status"] == "Released"]

# %%
df = all_df[filtered_columns]

# %%
all_df[all_df.columns[9:]]
# Out:
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# ...                                                  ...        ...
# 46623        Rising and falling between a man and woman.   0.072051
# 46624  An artist struggles to finish his work while a...   0.178241
# 46625  When one of her hits goes wrong, a professiona...   0.903007
# 46626  In a small town live two brothers, one a minis...   0.003503
# 46627  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# ...

# %%
all_df[["title", "poster_path"]].loc[0]
# Out:
# title                                 Toy Story
# poster_path    /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# Name: 0, dtype: object

# %%
all_df[all_df["poster_path"] == "pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg"][["title", "poster_path"]]
# Out:
# Empty DataFrame
# Columns: [title, poster_path]
# Index: []

# %%
all_df[all_df["original_title"] != all_df["title"]][["original_title", "title"]]
# Out:
#                          original_title                      title
# 28           La Cité des Enfants Perdus  The City of Lost Children
# 29                            摇啊摇，摇到外婆桥             Shanghai Triad
# 32     Guillaumet, les ailes du courage           Wings of Courage
# 57                           Il postino                The Postman
# 58                     Le confessionnal           The Confessional
# ...                                 ...                        ...
# 46615                               Maa                        Mom
# 46617        San Michele aveva un gallo  St. Michael Had a Rooster
# 46623                           رگ خواب                     Subdue
# 46624               Siglo ng Pagluluwal        Century of Birthing
# 46626               Satana likuyushchiy           Satan Triumphant
#
# [11786 rows x 2 columns]

# %%
all_df[["original_title", "title"]][0:50]
# Out:
#                       original_title                           title
# 0                          Toy Story                       Toy Story
# 1                            Jumanji                         Jumanji
# 2                   Grumpier Old Men                Grumpier Old Men
# 3                  Waiting to Exhale               Waiting to Exhale
# 4        Father of the Bride Part II     Father of the Bride Part II
# 5                               Heat                            Heat
# 6                            Sabrina                         Sabrina
# 7                       Tom and Huck                    Tom and Huck
# 8                       Sudden Death                    Sudden Death
# 9                          GoldenEye                       GoldenEye
# 10            The American President          The American President
# 11       Dracula: Dead and Loving It     Dracula: Dead and Loving It
# 12                             Balto                           Balto
# ...
